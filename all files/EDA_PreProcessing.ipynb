# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/FDA project/final_edit_2021.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-ee4c3dfbc718> in <module>()
#       1 import pandas as pd
# ----> 2 df = pd.read_csv('/content/drive/MyDrive/FDA project/final_edit_2021.csv')
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
#     687
# --> 688     return _read(filepath_or_buffer, kwds)
#     689
#     690
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     452
#     453     # Create the parser.
# --> 454     parser = TextFileReader(fp_or_buf, **kwds)
#     455
#     456     if chunksize or iterator:
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     946             self.options["has_index_names"] = kwds["has_index_names"]
#     947
# --> 948         self._make_engine(self.engine)
#     949
#     950     def close(self):
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1178     def _make_engine(self, engine="c"):
#    1179         if engine == "c":
# -> 1180             self._engine = CParserWrapper(self.f, **self.options)
#    1181         else:
#    1182             if engine == "python":
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    2008         kwds["usecols"] = self.usecols
#    2009
# -> 2010         self._reader = parsers.TextReader(src, **kwds)
#    2011         self.unnamed_cols = self._reader.unnamed_cols
#    2012
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/FDA project/final_edit_2021.csv'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df.tail()
# Out:
#         Unnamed: 0      mid      date  ... runs_last_5 innings_run run_sum
# 200550      200550  1254086  5/2/2021  ...          56         NaN   166.0
# 200551      200551  1254086  5/2/2021  ...          51         NaN   166.0
# 200552      200552  1254086  5/2/2021  ...          54         NaN   166.0
# 200553      200553  1254086  5/2/2021  ...          56         NaN   166.0
# 200554      200554  1254086  5/2/2021  ...          59       166.0   166.0
#
# [5 rows x 15 columns]

# %%
df=df[df['innings']==1]

# %%
#calculation of the runs
df1=df
runs_tot=[]
runs_a=0
for index, row in df1.iterrows():
  if index<=200554 and index>=0:
    if df1['overs'][index]==0.1:
      runs_a=0
    
    runs_a+=df1['runs'][index]
    runs_tot.append(runs_a)

# %%
len(runs_tot)
# Out:
# 103801

# %%
df['runs_tot']=runs_tot

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'mid', 'date', 'venue', 'bat_team', 'bowl_team',
#        'batsman', 'bowler', 'innings', 'runs', 'wickets', 'overs',
#        'runs_last_5', 'innings_run', 'run_sum', 'runs_tot'],
#       dtype='object')

# %%
#df=df[['striker', 'non_striker', 'Wicket', 'overs','run_sum','innings','runs_off_bat','player_dismissed','runs_tot']]
df.head(50)
# Out:
#     Unnamed: 0     mid       date  ... innings_run run_sum runs_tot
# 0            0  335982  4/18/2008  ...         NaN   221.0        1
# 1            1  335982  4/18/2008  ...         NaN   221.0        1
# 2            2  335982  4/18/2008  ...         NaN   221.0        2
# 3            3  335982  4/18/2008  ...         NaN   221.0        2
# 4            4  335982  4/18/2008  ...         NaN   221.0        2
# 5            5  335982  4/18/2008  ...         NaN   221.0        2
# 6            6  335982  4/18/2008  ...         NaN   221.0        3
# 7            7  335982  4/18/2008  ...         NaN   221.0        3
# 8            8  335982  4/18/2008  ...         NaN   221.0        7
# 9            9  335982  4/18/2008  ...         NaN   221.0       11
# 10          10  335982  4/18/2008  ...         NaN   221.0       17
# 11          11  335982  4/18/2008  ...         NaN   221.0       21
# 12          12  335982  4/18/2008  ...         NaN   221.0       21
# 13          13  335982  4/18/2008  ...         NaN   221.0       21
# 14          14  335982  4/18/2008  ...         NaN   221.0       21
# 15          15  335982  4/18/2008  ...         NaN   221.0       22
# 16          16  335982  4/18/2008  ...         NaN   221.0       26
# 17          17  335982  4/18/2008  ...         NaN   221.0       27
# 18          18  335982  4/18/2008  ...         NaN   221.0       27
# 19          19  335982  4/18/2008  ...         NaN   221.0       32
# 20          20  335982  4/18/2008  ...         NaN   221.0       38
# 21          21  335982  4/18/2008  ...         NaN   221.0       39
# 22          22  335982  4/18/2008  ...         NaN   221.0       43
# 23          23  335982  4/18/2008  ...         NaN   221.0       43
# 24          24  335982  4/18/2008  ...         NaN   221.0       44
# 25          25  335982  4/18/2008  ...         NaN   221.0       50
# 26          26  335982  4/18/2008  ...         NaN   221.0       54
# 27          27  335982  4/18/2008  ...         NaN   221.0       55
# 28          28  335982  4/18/2008  ...         NaN   221.0       59
# 29          29  335982  4/18/2008  ...         NaN   221.0       59
# 30          30  335982  4/18/2008  ...         NaN   221.0       60
# 31          31  335982  4/18/2008  ...         NaN   221.0       60
# 32          32  335982  4/18/2008  ...         NaN   221.0       61
# 33          33  335982  4/18/2008  ...         NaN   221.0       61
# 34          34  335982  4/18/2008  ...         NaN   221.0       61
# 35          35  335982  4/18/2008  ...         NaN   221.0       61
# 36          36  335982  4/18/2008  ...         NaN   221.0       61
# 37          37  335982  4/18/2008  ...         NaN   221.0       61
# 38          38  335982  4/18/2008  ...         NaN   221.0       62
# 39          39  335982  4/18/2008  ...         NaN   221.0       63
# 40          40  335982  4/18/2008  ...         NaN   221.0       64
# 41          41  335982  4/18/2008  ...         NaN   221.0       66
# 42          42  335982  4/18/2008  ...         NaN   221.0       67
# 43          43  335982  4/18/2008  ...         NaN   221.0       68
# 44          44  335982  4/18/2008  ...         NaN   221.0       68
# 45          45  335982  4/18/2008  ...         NaN   221.0       69
# 46          46  335982  4/18/2008  ...         NaN   221.0       70
# 47          47  335982  4/18/2008  ...         NaN   221.0       71
# 48          48  335982  4/18/2008  ...         NaN   221.0       72
# 49          49  335982  4/18/2008  ...         NaN   221.0       73
#
# [50 rows x 16 columns]

# %%
#filter for the first innings
df=df[df['innings']==1]

# %%
df1=df
person_a=df['striker'][0]    
person_b=df['non_striker'][0]
runs_a=0
runs_b=0
list_a=[]
list_b=[]

for index, row in df1.iterrows():
  #when there is no change in wicket, initialize the 2 players as a and b
  #exept when it is the start of the over, then initialize the players as a and b
  
  #initializing the person_a and person_b
  if index<=100190 and index>=0:

    if df1['overs'][index]==0.1:
      person_a=df1['striker'][index]
      person_b=df1['non_striker'][index]
      runs_a=0
      runs_b=0
      #print("visited first if initialize")

    elif not pd.isnull(df1.loc[index]['player_dismissed']):
      #change the person who lost the wicket
      #print("visited second if initialize")
      if person_a == df1.loc[index]['player_dismissed']:
        runs_a=0
        #update to the new person        
        x=[person_a,person_b]
        new_player=" "
        if df1['striker'][index+1] in x:
          new_player=df1['non_striker'][index+1]
        else:
          new_player=df1['striker'][index+1]        
        person_a=new_player
        
      else:
        runs_b=0
        #update to the new person        
        x=[person_a,person_b]
        new_player=" "
        if df1['striker'][index+1] in x:
          new_player=df1['non_striker'][index+1]
        else:
          new_player=df1['striker'][index+1]        
        person_b=new_player

    #adding the runs to the list
    if df['striker'][index]==person_a:
      # print(runs_a)
      runs_a+=df['runs_off_bat'][index]
      #print(df['runs_off_bat'][index])
      #print("runs scored by a is {} at index {}".format(runs_a,index))
      list_a.append(runs_a)
      list_b.append(runs_b)
    else:
      #print(runs_b)
      runs_b+=df['runs_off_bat'][index]
      #print(df['runs_off_bat'][index])
      #print("runs scored by b is {} at index {}".format(runs_b,index))
      list_a.append(runs_a)
      list_b.append(runs_b)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'striker'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-a6d80c9d95b9> in <module>()
#       1 df1=df
# ----> 2 person_a=df['striker'][0]
#       3 person_b=df['non_striker'][0]
#       4 runs_a=0
#       5 runs_b=0
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2904             if self.columns.nlevels > 1:
#    2905                 return self._getitem_multilevel(key)
# -> 2906             indexer = self.columns.get_loc(key)
#    2907             if is_integer(indexer):
#    2908                 indexer = [indexer]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
# -> 2900                 raise KeyError(key) from err
#    2901
#    2902         if tolerance is not None:
#
# KeyError: 'striker'

# %%
df1.shape
# Out:
# (100191, 9)

# %%
required_striker=max(list_a,list_b)
required_non_striker=min(list_a,list_b)

# %%
df['required_striker']=required_striker
df['required_non_striker']=required_non_striker

# %%
df.head()
# Out:
#        striker  non_striker  ...  required_striker  required_non_striker
# 0   SC Ganguly  BB McCullum  ...                 0                     0
# 1  BB McCullum   SC Ganguly  ...                 0                     0
# 2  BB McCullum   SC Ganguly  ...                 0                     0
# 3  BB McCullum   SC Ganguly  ...                 0                     0
# 4  BB McCullum   SC Ganguly  ...                 0                     0
#
# [5 rows x 10 columns]

# %%
df1.to_csv('ready_for_ml.csv')

# %%
df1=df[df['innings']==1]

# %%
df1.shape
# Out:
# (100191, 10)

# %%
df3=pd.read_csv('ready_for_ml.csv')

# %%
df3.shape
# Out:
# (100191, 11)

# %%
df3.columns
# Out:
# Index(['Unnamed: 0', 'striker', 'non_striker', 'Wicket', 'overs', 'run_sum',
#        'innings', 'runs_off_bat', 'player_dismissed', 'required_striker',
#        'required_non_striker', 'runs'],
#       dtype='object')

# %%
df3['runs']=runs_tot

# %%
df3.tail()
# Out:
#         Unnamed: 0   striker  ... required_non_striker  runs
# 100186      193500  AR Patel  ...                    0   149
# 100187      193501   SS Iyer  ...                    0   149
# 100188      193502   SS Iyer  ...                    0   149
# 100189      193503   SS Iyer  ...                    0   155
# 100190      193504   SS Iyer  ...                    0   156
#
# [5 rows x 12 columns]

# %%
df3.to_csv('ready_for_ml_v1.csv')
